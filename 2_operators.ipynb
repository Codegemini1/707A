# %%
# Arithmetic operators

# %%
10 + 6
# Out:
# 16

# %%
5 - 1
# Out:
# 4

# %%
10 * 5
# Out:
# 50

# %%
'Hello' * 5
# Out:
# 'HelloHelloHelloHelloHello'

# %%
10 / 2
# Out:
# 5.0

# %%
10 % 2
# Out:
# 0

# %%
10 % 3
# Out:
# 1

# %%
2 ** 2
# Out:
# 4

# %%
3 ** 2
# Out:
# 9

# %%
15 / 2
# Out:
# 7.5

# %%
15 // 2
# Out:
# 7

# %%
212 / 3
# Out:
# 70.66666666666667

# %%
212 // 3
# Out:
# 70

# %%
# Assignment operator

# %%
a = 5

# %%
a + 1
# Out:
# 6

# %%
a = a + 1

# %%
a
# Out:
# 6

# %%
b = 5

# %%
b += 1

# %%
b
# Out:
# 6

# %%
b
# Out:
# 6

# %%
b - 2
# Out:
# 4

# %%
b = b - 2

# %%
b
# Out:
# 4

# %%
b = b * 2

# %%
b
# Out:
# 8

# %%
b *= 2

# %%
b
# Out:
# 16

# %%
c = 9

# %%
c ** 2
# Out:
# 81

# %%
c **= 2

# %%
c
# Out:
# 81

# %%
1 == 1
# Out:
# True

# %%
'h' == 'h'
# Out:
# True

# %%
'Hello' == 'hello'
# Out:
# False

# %%
1 != 5
# Out:
# True

# %%
1 != 1
# Out:
# False

# %%
'h' != 'o'
# Out:
# True

# %%
'h' != 'h'
# Out:
# False

# %%
10 > 2
# Out:
# True

# %%
5 > 10
# Out:
# False

# %%
10 < 20
# Out:
# True

# %%
10 < 5
# Out:
# False

# %%
5 > 5
# Out:
# False

# %%
5 < 5
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
10 >= 20
# Out:
# False

# %%
10 >= 10
# Out:
# True

# %%
35 >= 35
# Out:
# True

# %%
10 <= 10
# Out:
# True

# %% [markdown]
# # Logical Operator

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %% [markdown]
# # Operations

# %%
first_name = 'Vaibhav'
last_name = 'Bhosale'

# %%
first_name + last_name
# Out:
# 'VaibhavBhosale'

# %%
first_name + ' ' + last_name
# Out:
# 'Vaibhav Bhosale'

# %%
age = 60

# %%
print(first_name, last_name, age)
# Out:
# Vaibhav Bhosale 60

# %%
first_name + last_name + age
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 first_name + last_name + age
#
# TypeError: can only concatenate str (not "int") to str

# %%
first_name + last_name, age
# Out:
# ('VaibhavBhosale', 60)

# %%
print(first_name + last_name, age)
# Out:
# VaibhavBhosale 60

# %%
print(f'Your first name is {first_name} and your last name is {last_name} and age is {age}')
# Out:
# Your first name is Vaibhav and your last name is Bhosale and age is 60
