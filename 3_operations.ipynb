# %%
num = 1
num2 = 2

# %%
num + num2
# Out:
# 3

# %%
10 + 'hello'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 10 + 'hello'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
name = input('Write your first name')
# Out:
# Write your first name Om

# %%
name
# Out:
# 'Om'

# %%
name = input('Write your first name')
print(f'Your good name is {name}')
# Out:
# Write your first name Sham
# Your good name is Sham

# %%
type(name)
# Out:
# str

# %%
age = input('Enter your age')
print(f'Your age is {age}')
# Out:
# Enter your age 80
# Your age is 80

# %%
type(age)
# Out:
# str

# %%
'80'
# Out:
# '80'

# %%
int('80')
# Out:
# 80

# %%
str(150)
# Out:
# '150'

# %%
age = int(input('Write your age'))
# Out:
# Write your age 80

# %%
type(age)
# Out:
# int

# %%
print(f'Your age is {age}')
# Out:
# Your age is 80

# %%
height = int(input('Write your height in feet'))
# Out:
# Write your height in feet dfghdujkgf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 height = int(input('Write your height in feet'))
#
# ValueError: invalid literal for int() with base 10: 'dfghdujkgf'

# %%
height = float(input('Height'))
# Out:
# Height 6.232

# %%
height
# Out:
# 6.232

# %%
weight = float(input('Weight'))
# Out:
# Weight 50

# %%
weight
# Out:
# 50.0

# %% [markdown]
# # Data Strectures

# %%
l = [10,20,30,40,50]

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
type(l)
# Out:
# list

# %%
names = ['Om', 'ram', 'sham', 'ganesh']

# %%
names
# Out:
# ['Om', 'ram', 'sham', 'ganesh']

# %%
names[1]
# Out:
# 'ram'

# %%
names[0]
# Out:
# 'Om'

# %%
names[3]
# Out:
# 'ganesh'

# %%
names
# Out:
# ['Om', 'ram', 'sham', 'ganesh']

# %%
names[-1]
# Out:
# 'ganesh'

# %%
names[2]
# Out:
# 'sham'

# %%
names[2] = 'Vaibhav'

# %%
names
# Out:
# ['Om', 'ram', 'Vaibhav', 'ganesh']

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l[2]
# Out:
# 30

# %%
names
# Out:
# ['Om', 'ram', 'Vaibhav', 'ganesh']

# %%
c = ['White', 'Black', 'Red', 'Pink', 'Orange', 'Blue']

# %%
c
# Out:
# ['White', 'Black', 'Red', 'Pink', 'Orange', 'Blue']

# %%
c[1:4]
# Out:
# ['Black', 'Red', 'Pink']

# %%
c[0:3]
# Out:
# ['White', 'Black', 'Red']

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l[1:4]
# Out:
# [20, 30, 40]

# %%
c
# Out:
# ['White', 'Black', 'Red', 'Pink', 'Orange', 'Blue']

# %%
c[3:5]
# Out:
# ['Pink', 'Orange']

# %%
c[3:6]
# Out:
# ['Pink', 'Orange', 'Blue']

# %%
c[:]
# Out:
# ['White', 'Black', 'Red', 'Pink', 'Orange', 'Blue']

# %%
c[2:]
# Out:
# ['Red', 'Pink', 'Orange', 'Blue']

# %%
c[:3]
# Out:
# ['White', 'Black', 'Red']

# %%
c
# Out:
# ['White', 'Black', 'Red', 'Pink', 'Orange', 'Blue']

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
# c[start:end]

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l[:]
# Out:
# [10, 20, 30, 40, 50]

# %%
l[0:5:1] # start : end : jump
# Out:
# [10, 20, 30, 40, 50]

# %%
l[::2]
# Out:
# [10, 30, 50]

# %%
c
# Out:
# ['White', 'Black', 'Red', 'Pink', 'Orange', 'Blue']

# %%
c[::2]
# Out:
# ['White', 'Red', 'Orange']

# %%
l2 = [1,2,3,4,5,6,7,8,9]

# %%
l2
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
l2[::-1]
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
l2[7:2:]
# Out:
# []
